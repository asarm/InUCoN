# %%
import pandas as pd
import numpy as np

# %%
consistency_df = pd.read_csv('consistency_combinations.csv')

# %%
consistency_df[consistency_df.metric == 'euclidean'].sort_values(by="average") # pearson, , distCorr
# Out:
#     threshold  tsWeight     metric    trial1    trial2    trial3    trial4  \
# 15       0.25      0.85  euclidean  0.000000  0.002646  0.003623  0.002646
# 13       0.25      0.75  euclidean  0.000000  0.005272  0.002584  0.002976
# 2        0.20      0.20  euclidean  0.006380  0.000000  0.000000  0.006667
# 8        0.25      0.50  euclidean  0.000000  0.005878  0.003810  0.003820
# 3        0.20      0.25  euclidean  0.003300  0.003300  0.000000  0.006568
# 0        0.20      0.10  euclidean  0.003086  0.003058  0.000000  0.006117
# 16       0.25      0.90  euclidean  0.006211  0.006428  0.002070  0.004141
# 1        0.20      0.15  euclidean  0.003205  0.009346  0.000000  0.006320
# 12       0.25      0.70  euclidean  0.002315  0.004730  0.007485  0.004730
# 10       0.25      0.60  euclidean  0.006524  0.004090  0.006707  0.006472
# 14       0.25      0.80  euclidean  0.003205  0.000000  0.012673  0.011819
# ...
